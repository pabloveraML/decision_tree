# %% [markdown]
# ## Cargamos todas las bibliotecas necesarias para ejecutar todos los métodos del jupyter.

# %% [markdown]
# Es buena costumbre cargarlos al principio, asi no se estar cargando en memoria repetidas veces cada paquete

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_validate

from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
#import pydotplus

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
import matplotlib
warnings.filterwarnings('ignore')

# %%
sns.set(style="darkgrid")
plt.rcParams['figure.figsize'] = [30, 10]
plt.rcParams['font.size'] = 2

# %% [markdown]
# ### Creación de funciones auxiliares

# %%
def discretize(df, column):
    q1 = df_final[column].quantile(.25)
    q2 = df_final[column].quantile(.5)
    q3 = df_final[column].quantile(.75)
    df[column+"_in_q1"] = 0
    df[column+"_in_q2"] = 0
    df[column+"_in_q3"] = 0
    df[column+"_in_q4"] = 0
    df[column+"_in_q1"] = list(map(lambda x: 1 if x <=q1 else 0, df[column]))
    df[column+"_in_q2"] = list(map(lambda x: 1 if (q1 < x and x <=q2) else 0, df[column]))
    df[column+"_in_q3"] = list(map(lambda x: 1 if (q2 < x and x <=q3) else 0, df[column]))
    df[column+"_in_q4"] = list(map(lambda x: 1 if x>q3 else 0, df[column]))
    df.drop(column, axis=1, inplace=True)
    return df

# %%
def is_object(df,column,object_name):
    df["is_"+str(object_name)] = list(map(lambda x: 1 if x == object_name else 0, df[column]))
    return df

# %%
def find_and_replace_nans(df,col,rate_to_complete):
    
    index_list = df[col][df[col].isnull()].sample(frac=rate_to_complete,random_state=1).index.tolist()
    
    if len(index_list)>0:
        moda = df[(~df[col].isnull())][col].mode()[0]
        df.loc[index_list,col] = moda
    return df
    
def complete_nans(df,null_cols,rate_to_complete,method):
    if method=="moda_por_clase":
        for col in null_cols:
            df0 = find_and_replace_nans(df[df.target==0.0],col,rate_to_complete)
            df1 = find_and_replace_nans(df[df.target==1.0],col,rate_to_complete)
            df = pd.concat([df0,df1])
    else:
        for col in null_cols:
            df = find_and_replace_nans(df,col,rate_to_complete)
    
    return df.dropna()

# %%
def preprocess(df, metodo, rate_to_complete):
    
    # Extraemos las filas de la columna 'model' que tienen valores NaNs y luego los completamos con un valor por defecto
    
    #model_null_indexes = df[df.model.isnull()].index.tolist()
    #df.loc[model_null_indexes,"model"] = "other other"
    
    df['model'] = df['model'].fillna('other other')
    
    # Obtenemos las columnas que tienen al menos un NaN
    cols_in_null = df.columns[df.isnull().sum(axis=0)>0].tolist()
    
    # Los completamos con un rate_to_complete y utilizando un determinado metodo
    df_comp = complete_nans(df,cols_in_null,rate_to_complete,metodo)
    
    # Discretizamos las columnas que ya sabemos que tienen una distribucion dada (Chi, Normal)
    # (Se usan cuantiles para ver en qué segmento caen)
    for column in ["diff_time_days_minnone","diff_time_dayssearch engine hit","COUNT(users_logs)","number_visits_model","diff_time_daysbrand listing","diff_time_daysnone"]:
        df_comp = discretize(df_comp,column)
    
    # De la columna 'model' extraemos marca y modelo del celular visitado o  comprado
    df_comp["marca"] = df_comp.model.str.split(" ",1,expand=True)[0]
    df_comp["modelo"] = df_comp.model.str.split(" ",1,expand=True)[1]
    
    # Determinamos de que marca se trata
    df_comp["is_iphone"] = list(map(lambda x: 1 if x=="iPhone" else 0, df_comp["marca"]))
    df_comp["is_samsung"] = list(map(lambda x: 1 if x=="Samsung" else 0, df_comp["marca"]))
    df_comp["is_motorola"] = list(map(lambda x: 1 if x=="Motorola" else 0, df_comp["marca"]))
    df_comp["is_lg"] = list(map(lambda x: 1 if x=="LG" else 0, df_comp["marca"]))
    df_comp["is_sony"] = list(map(lambda x: 1 if x=="Sony" else 0, df_comp["marca"]))
    df_comp["is_other"] = list(map(lambda x: 1 if (x!="Sony" and x!="LG" and x!="Motorola" and x!="Samsung" and x!="iPhone") else 0, df_comp["marca"]))
    
    # determinamos de que modelo se trata
    pop_models = ['6','5s','6S','Galaxy J5','7','7 Plus','Galaxy S8','Galaxy S7','Galaxy S7 Edge','Galaxy J7 Prime','Moto G2 3G Dual','Galaxy S6 Edge','Galaxy S6 Flat','5c','6S Plus','Galaxy J7','6 Plus','Moto G4 Plus','SE','Galaxy Gran Prime Duos TV','4S','Galaxy S8 Plus','5','Moto G3 4G','Galaxy A5 2017','Moto X Play 4G Dual','Moto G5 Plus','Galaxy A7 2017','Moto X2','Galaxy A5']
    for model in pop_models:
        df_comp = is_object(df_comp,"modelo",model)

    df_comp["is_other_model"] = list(map(lambda x: 1 if x not in pop_models else 0, df_comp["modelo"]))
    
    # Eliminamos las columnas con strings
    df_comp.drop(["model","marca","modelo"],axis=1,inplace=True)
    
    return df_comp

# %%
def test_completitud(train, test, feature_columns, metodo, best_depth):
    dtree = DecisionTreeClassifier(max_depth=5, criterion='gini') 
    completitud_precision_tamanio = {"completitud":[], "precision":[], "tamanio":[]}
    for p in np.arange(0.0,.85,.05):   
        df_train_p = preprocess(train,metodo,p)
        scores = cross_validate(dtree, # Instancia de árbol a entrenar en cada fold
                            df_train_p[feature_columns].values, # X_train features
                            df_train_p["target"].values, # Y_train targets
                            scoring=scoring, # Pedimos que para fold se ejecute esta lista de scorings
                            return_train_score = True, # Queremos ver los scorings de los training folds
                            return_estimator = True, # Ademas, pedimos que se nos devuelvan los dtrees de entrenados
                            cv=5, # Establecemos la cantidad de particiones para realizar la Validación cruzada
                            n_jobs = -1 # Pedimos que se ejecute en paralelo, utilizando todos los cores
                           )
        best_dtree_index = np.argmax(scores["test_roc_auc"])
        best_btree = scores["estimator"][best_dtree_index]

        y_esperado = test.target.values
        y_pred = best_btree.predict(test[feature_columns].values)

        accuracy = accuracy_score(y_esperado, y_pred)
        tamanio = best_btree.tree_.node_count

        completitud_precision_tamanio["completitud"].append(100.0*p)
        completitud_precision_tamanio["precision"].append(accuracy)
        completitud_precision_tamanio["tamanio"].append(tamanio)
        
    return completitud_precision_tamanio

# %% [markdown]
# ## Cargamos los datasets para construir el dataset final

# %%
df_first = pd.read_csv('../../data_aa/first_part_dataset.csv')

df_second = pd.read_csv('../../data_aa/second_part_dataset.csv')

df_thrid = pd.read_csv('../../data_aa/thrid_part_dataset.csv')

# %%
df_first = df_first.rename(columns={'person_id': 'person'})

df_first = df_first.drop(columns=['Unnamed: 0'])

# %%
df_second.columns.values
# Out:
# array(['Unnamed: 0', 'person', 'diff_time_days_minnone',
#        'diff_time_daysnone', 'diff_time_dayscheckout',
#        'diff_time_daysconversion', 'diff_time_daysbrand listing',
#        'diff_time_dayssearch engine hit', 'diff_time_start_end', 'model',
#        'number_visits_model'], dtype=object)

# %%
df_second = df_second.drop(columns=['Unnamed: 0'])

# %%
df_thrid.columns.values
# Out:
# array(['Unnamed: 0', 'person', 'COUNT(users_logs)', 'avg_time_events'],
#       dtype=object)

# %%
df_thrid = df_thrid.drop(columns=['Unnamed: 0'])

# %%
df_final = pd.merge(df_first, df_second, on='person', how='left')

df_final = pd.merge(df_final, df_thrid, on='person', how='left')

# %%
df_final.target.isin([1.0]).shape
# Out:
# (19414,)

# %% [markdown]
# Significado de las columnas:
#
#  - Las columnas 'Android', 'BlackBerry', 'Chrome', 'FreeBSD', 'Linux', 'Mac', 'Tizen', 'Ubuntu', 'Unknown', 'Windows','iOS' indican la cantidad de veces que cada usuario ingreso a la pagina de Trocafone utilizando uno de esos esos sistemas operativos. Por ejemplo, si el valor de 'Android' para un usuario es 2 siginfica que ese usuario entro a la pagina dos veces desde un dispositivo con un sistema operativo Android
#
#  - Las columnas 'Computer', 'Smartphone', 'Tablet' indican la cantidad de veces que cada usuario ingreso a la pagina de Trocafone utilizando uno de esos dispositivos
#
#  - Las columnas 'ad campaign hit', 'brand listing', 'checkout', 'conversion', 'generic listing', 'lead','search engine hit', 'searched products', 'staticpage','viewed product', 'visited site' indican la cantidad de veces que cada usuario realizo cada uno de esos eventos
#
#  - La columna 'diff_time_days_minnone' indica la cantidad de tiempo que paso desde el primer evento que realizo el usuario hasta el 2018/06/01
#
#  - La columna 'diff_time_daysnone' indica la cantidad de tiempo que paso desde el ultimo evento que el usuario realizo en la pagina hasta el 2018/06/01
#
#  - La columna 'diff_time_dayscheckout' indica la cantidad de tiempo que paso desde que el usuario realizo el ultimo checkout hasta el 2018/06/01
#
#  - La columna 'diff_time_daysconversion' indica la cantidad de tiempo que paso desde que el usuario realizo la ultima conversion hasta el 2018/06/01
#
#  - La columna 'diff_time_daysbrand listing' indica la cantidad de tiempo que paso desde que el usuario realizo la ultima brand listing hasta el 2018/06/01
#
#  - La columna 'diff_time_dayssearch engine hit' indica la cantidad de tiempo que paso desde que el usuario realizo el ultimo engine hit hasta el 2018/06/01
#
#  - La columna 'diff_time_start_end' indica la cantidad de tiempo que paso entre el primer evento que realizo el usuario en la pagina y el ultimo
#
#  - La columna 'model' indica el modelo de celuar que el usuario mas veces visito
#
#  - La columna 'number_visits_model' indica cuantas veces el usuario visito el celular que mas visito
#
#  - La columna 'COUNT(users_logs)' indica la cantidad de eventos que el usuario realizo en la pagina
#
#  - La columna 'avg_time_events' indica el tiempo promedio que paso entre los eventos realizados por cada usuario

# %% [markdown]
# ### Eliminamos las columnas con muy pocas variables o alta corrleación (Ej. Windows ~ Computer)

# %%
df_final.drop(["BlackBerry","Chrome","FreeBSD","Linux","Mac","Other","Tizen","Ubuntu","Unknown","Windows","person"],
              axis=1,
              inplace=True)

# %% [markdown]
# ### Transformamos algunas columnas para que su distribución se ajuste a una Chi cuadrado o Normal. Luego discretizamos por cuantiles

# %%
df_final.loc[:,"diff_time_daysnone"] = np.log10(df_final["diff_time_daysnone"]+1.)
df_final.loc[:,"diff_time_days_minnone"] = np.log10(df_final.diff_time_days_minnone+1.)
df_final.loc[:,"diff_time_dayssearch engine hit"] = np.log10(df_final["diff_time_dayssearch engine hit"]+1.0)
df_final.loc[:,"COUNT(users_logs)"] = np.log10(df_final["COUNT(users_logs)"]+1.)
df_final.loc[:,"number_visits_model"] = np.log10(1.+df_final.number_visits_model)
df_final.loc[:,"diff_time_daysbrand listing"] = np.log10(01.+df_final["diff_time_daysbrand listing"])

# %%
df_final['model'].head()
# Out:
# 0                         NaN
# 1                    iPhone 7
# 2                   iPhone 6S
# 3    Motorola Moto G2 3G Dual
# 4      Samsung Galaxy S8 Plus
# Name: model, dtype: object

# %% [markdown]
# ### En el siguiente metodo  se realiza todo el preprocess de los datos.

# %%
df_completo = preprocess(df_final.copy(),"moda",1.)
# Out:
# Completando columna diff_time_dayscheckout
# Moda: 2.2
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (0,)
# Completando columna diff_time_daysconversion
# Moda: 1.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (0,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (0,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (0,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (0,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (0,)

# %% [markdown]
# ### Vamos a seleccionar solo 980 casos que no realizaron una compra para balancear el dataset

# %%
df_completo_reduced_1 = df_completo[df_completo['target']==1]
print(len(df_completo_reduced_1.index))
# Out:
# 980

# %%
df_completo_reduced_0 = df_completo[df_completo['target']==0].sample(n=980, random_state=1)
print(len(df_completo_reduced_0.index))
# Out:
# 980

# %%
df_train = pd.concat([df_completo_reduced_1, df_completo_reduced_0])
del df_completo_reduced_0, df_completo_reduced_1

# %% [markdown]
# ### Nos quedamos con aquellas columnas que no sean target

# %%
feature_columns = list(set(df_train.columns.tolist())-set(["target"]))

# %% [markdown]
# ### Obtenemos el dataset de test y lo eliminamos del dataset de train

# %%
df_test = df_train.sample(frac=0.2, random_state=2)
df_train.drop(df_test.index,axis=0,inplace=True)
train_indexes = df_train.index.tolist()

# %%
len(df_test)
# Out:
# 392

# %% [markdown]
# ### Verificamos el balance de categorías en cada datset

# %%
N_train = df_train.shape[0]*1.
N_test = df_test.shape[0]*1.

N_train_1 = df_train.target.sum()
N_train_0 = df_train.shape[0]*1.-N_train_1

N_test_1 = df_test.target.sum()
N_test_0 = df_test.shape[0]*1.-N_test_1

# %%
print("Porcentaje de casos positivos en el train: %" + str(100.0*N_train_1/N_train))
print("Porcentaje de casos positivos en el test: %" + str(100.0*N_test_1/N_test))
# Out:
# Porcentaje de casos positivos en el train: %50.255102040816325
# Porcentaje de casos positivos en el test: %48.97959183673469

# %% [markdown]
# ## Utilizando únicamente el dataset de train ejecutamos 5-fold Cross Validation

# %%
scoring = ['accuracy','roc_auc']

# %%
dtree = DecisionTreeClassifier(max_depth=3, criterion='gini')

# %%
scores = cross_validate(dtree, # Instancia de árbol a entrenar en cada fold
                        df_train[feature_columns].values, # X_train features
                        df_train["target"].values, # Y_train targets
                        scoring=scoring, # Pedimos que para fold se ejecute esta lista de scorings
                        return_train_score = True, # Queremos ver los scorings de los training folds
                        return_estimator = True, # Ademas, pedimos que se nos devuelvan los dtrees de entrenados
                        cv=5, # Establecemos la cantidad de particiones para realizar la Validación cruzada
                        n_jobs = -1 # Pedimos que se ejecute en paralelo, utilizando todos los cores
                       )

# %% [markdown]
# ### Cargamos los resultados en un DF de Pandas

# %%
cv_5_fold_resultados = pd.DataFrame(scores)
cv_5_fold_resultados.drop(["fit_time","score_time","estimator"],axis=1,inplace=True)

# %%
cv_5_fold_resultados
# Out:
#    test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# 0       0.732484        0.767145      0.791728       0.828612
# 1       0.767516        0.763955      0.836356       0.824302
# 2       0.707006        0.779904      0.753185       0.842019
# 3       0.760383        0.768127      0.802344       0.833754
# 4       0.766773        0.764143      0.812388       0.830726

# %% [markdown]
# ### Calculamos los estadisticos de cada experimento, tanto para train como para test

# %%
cv_5_fold_resultados.describe()
# Out:
#        test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# count       5.000000        5.000000      5.000000       5.000000
# mean        0.746833        0.768655      0.799200       0.831883
# std         0.026463        0.006549      0.030568       0.006629
# min         0.707006        0.763955      0.753185       0.824302
# 25%         0.732484        0.764143      0.791728       0.828612
# 50%         0.760383        0.767145      0.802344       0.830726
# 75%         0.766773        0.768127      0.812388       0.833754
# max         0.767516        0.779904      0.836356       0.842019

# %% [markdown]
# ### Seleccionamos el árbol que mejor accuracy haya tenido durante el train

# %%
best_dtree_index = np.argmax(scores["test_accuracy"]*scores["test_roc_auc"])

# %%
best_btree = scores["estimator"][best_dtree_index]

# %% [markdown]
# ### Evaluamos su accuracy sobre el 20% restante del dataset que no formó parte del 5-fold CV

# %%
y_esperado = df_test.target.values
y_pred = best_btree.predict(df_test[feature_columns].values)

# %%
print("Score validation: " + str(accuracy_score(y_esperado, y_pred)))
# Out:
# Score validation: 0.7831632653061225

# %%
# dot_data = StringIO()
# export_graphviz(best_btree, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# Image(graph.create_png())

# %% [markdown]
# ## Volvemos a correr el 5-fold CV pero completado el dataset de train con un dado porcentaje de completitud

# %%
df_train_80 = preprocess(df_final.loc[train_indexes].copy(),"moda",.25)
# Out:
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (406,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (1003,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (490,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (287,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (46,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (5,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_final.loc[train_indexes].shape
# Out:
# (1568, 28)

# %%
scores = cross_validate(dtree, # Instancia de árbol a entrenar en cada fold
                        df_train_80[feature_columns].values, # X_train features
                        df_train_80["target"].values, # Y_train targets
                        scoring=scoring, # Pedimos que para fold se ejecute esta lista de scorings
                        return_train_score = True, # Queremos ver los scorings de los training folds
                        return_estimator = True, # Ademas, pedimos que se nos devuelvan los dtrees de entrenados
                        cv=5, # Establecemos la cantidad de particiones para realizar la Validación cruzada
                        n_jobs = -1 # Pedimos que se ejecute en paralelo, utilizando todos los cores
                       )

# %%
cv_5_fold_resultados = pd.DataFrame(scores)
cv_5_fold_resultados.drop(["fit_time","score_time","estimator"],axis=1,inplace=True)

# %%
cv_5_fold_resultados
# Out:
#    test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# 0       0.698413        0.714286      0.682952       0.806379
# 1       0.612903        0.772358      0.615135       0.835405
# 2       0.639344        0.793522      0.675556       0.850739
# 3       0.688525        0.789474      0.730000       0.848535
# 4       0.622951        0.740891      0.676111       0.838295

# %%
cv_5_fold_resultados.describe()
# Out:
#        test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# count       5.000000        5.000000      5.000000       5.000000
# mean        0.652427        0.762106      0.675951       0.835871
# std         0.038794        0.033830      0.040832       0.017729
# min         0.612903        0.714286      0.615135       0.806379
# 25%         0.622951        0.740891      0.675556       0.835405
# 50%         0.639344        0.772358      0.676111       0.838295
# 75%         0.688525        0.789474      0.682952       0.848535
# max         0.698413        0.793522      0.730000       0.850739

# %%
best_dtree_index = np.argmax(scores["test_accuracy"]*scores["test_roc_auc"])

# %%
best_btree = scores["estimator"][best_dtree_index]

# %%
y_esperado = df_test.target.values
y_pred = best_btree.predict(df_test[feature_columns].values)

# %%
print("Score validation: " + str(accuracy_score(y_esperado, y_pred)))
# Out:
# Score validation: 0.6045918367346939

# %%
# dot_data = StringIO()
# export_graphviz(best_btree, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# Image(graph.create_png())

# %% [markdown]
# ## Analisis de completitud vs tamanio del arbol

# %%
test_moda = test_completitud(train=df_final.loc[train_indexes].copy(),
                 test=df_test.copy(),
                 feature_columns=feature_columns,
                 metodo="moda",
                 best_depth=5
                )
# Out:
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (515,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (1270,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (621,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (364,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (58,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (463,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (1143,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (559,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (328,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (52,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (6,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (394,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (972,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (475,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (279,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (44,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (5,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (315,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (778,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (380,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (223,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (35,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (4,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (236,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (584,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (285,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (167,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (26,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (3,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (165,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (409,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (199,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (117,)
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (18,)
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (2,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (1,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (3,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (1,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (1,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# Completando columna diff_time_dayscheckout
# Moda: 0.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (0,)
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (1,)
# Completando columna diff_time_daysbrand listing
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (0,)
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.07918124604762482
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (0,)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/maestria/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (0,)

# %%
test_moda_por_clase = test_completitud(train=df_final.loc[train_indexes].copy(),
                 test=df_test.copy(),
                 feature_columns=feature_columns,
                 metodo="moda_por_clase",
                 best_depth=5
                )
# Out:
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (110,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (405,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (671,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (599,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (377,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (244,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (242,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (122,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (30,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (28,)
# Completando clase 0
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (104,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (383,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (635,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (568,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (357,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (231,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (229,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (115,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (29,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (26,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (6,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (99,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (362,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (600,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (536,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (337,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (218,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (217,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (109,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (27,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (25,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (6,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (93,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (341,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (565,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (505,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (318,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (206,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (204,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (102,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (26,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (23,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (6,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (87,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (320,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (530,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (473,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (298,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (193,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (191,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (96,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (24,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (22,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (5,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (81,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (298,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (494,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (442,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (278,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (180,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (178,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (90,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (22,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (20,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (5,)
# Completando clase 1
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (75,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (277,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (459,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (410,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (258,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (167,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (166,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (83,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (21,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (19,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (5,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (70,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (256,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (424,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (379,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (238,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (154,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (153,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (77,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (19,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (17,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (4,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (64,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (234,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (388,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (347,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (218,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (141,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (140,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (70,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (18,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (16,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (4,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (58,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (213,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (353,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (315,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (199,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (129,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (127,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (64,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (16,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (15,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (3,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (52,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (192,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (318,)
# Completando clase 1
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (284,)
# Completando clase 0
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (179,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (116,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (115,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (58,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (14,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (13,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (3,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (46,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (170,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (282,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (252,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (159,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (103,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (102,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (51,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (13,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (12,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (3,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (41,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (149,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (247,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (221,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (139,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (90,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (89,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (45,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (11,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (10,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (2,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (35,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (128,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (212,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (189,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (119,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (77,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (76,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (38,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (10,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (9,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (2,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (29,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (106,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (176,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (158,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (99,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (64,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (64,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (32,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (8,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (7,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (2,)
# Completando clase 1
# Completando clase 0
# Completando columna diff_time_dayscheckout
# Moda: 10.3
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (23,)
# Completando clase 1
# Completando columna diff_time_dayscheckout
# Moda: 0.1
# Cantidad restante de NULLs en columna diff_time_dayscheckout: (85,)
# Completando clase 0
# Completando columna diff_time_daysconversion
# Moda: 8.2
# Cantidad restante de NULLs en columna diff_time_daysconversion: (141,)
# Completando clase 1
# Completando columna diff_time_daysconversion
# Moda: 1.0
# Cantidad restante de NULLs en columna diff_time_daysconversion: (126,)
# Completando clase 0
# /anaconda2/envs/maestria/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Completando columna diff_time_daysbrand listing
# Moda: 1.0530784434834197
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (79,)
# Completando clase 1
# Completando columna diff_time_daysbrand listing
# Moda: 0.11394335230683679
# Cantidad restante de NULLs en columna diff_time_daysbrand listing: (51,)
# Completando clase 0
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.04139268515822508
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (51,)
# Completando clase 1
# Completando columna diff_time_dayssearch engine hit
# Moda: 0.146128035678238
# Cantidad restante de NULLs en columna diff_time_dayssearch engine hit: (26,)
# Completando clase 0
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (6,)
# Completando clase 1
# Completando columna number_visits_model
# Moda: 0.3010299956639812
# Cantidad restante de NULLs en columna number_visits_model: (6,)
# Completando clase 0
# Completando columna avg_time_events
# Moda: 0.0
# Cantidad restante de NULLs en columna avg_time_events: (1,)
# Completando clase 1

# %%
sns.set(font_scale=2)
fig, ax1 = plt.subplots()
ax1.plot(test_moda["completitud"],test_moda["tamanio"], linewidth=3.0)
ax1.set_xlabel('Porcentaje de completitud')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Cantidad de nodos del arbol')
plt.title("Imputacion de datos faltantes por moda")
plt.show()

# %%
fig, ax1 = plt.subplots()
ax1.plot(test_moda_por_clase["completitud"],test_moda_por_clase["tamanio"], linewidth=3.0)
ax1.set_xlabel('Porcentaje de completitud')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Cantidad de nodos del arbol')
plt.title("Imputacion de datos faltantes por moda")
plt.show()

# %% [markdown]
# ## 2.4 Tolerancia al ruido

# %% [markdown]
# ### a) y b)

# %%
import random

# %% [markdown]
# #### Creamos una funcion que genera un array de un largo determinado con valores 0 y un porcentage de valores random. Los valores random que se generen van a depender de la media de la columna para la cual quiere generarse ruido

# %%
def create_array_noise(elements_in_column, percentage_noise, mean_column):
    
    number_noise = round(elements_in_column*percentage_noise)
    
    mu, sigma = 0, mean_column
    
    noise = np.random.normal(mu, sigma, [number_noise,1])
    
    array_noise = noise.tolist()
    
    array_noise_final = []
    
    for item in array_noise:
        
        array_noise_final.append(item[0])
    
    array_no_noise = [0]*(elements_in_column - number_noise)
    
    noise = array_noise_final + array_no_noise
    
    random.shuffle(noise)
    
    return noise

# %% [markdown]
# #### Creamos una funcion que, utilizando la funcion anterior, agrega un % de ruido al atributo que indiquemos de un dataset determinado

# %%
def generate_dataset_with_noise(df, name_attribute, percentage_noise):
    
    dataframe = df.copy()
    
    number_observations = len(dataframe[name_attribute].values)
    
    mean_column_attribute = dataframe[name_attribute].mean()
    
    array_noise = create_array_noise(number_observations, percentage_noise, mean_column_attribute)
    
    dataframe[name_attribute] = dataframe[name_attribute] + array_noise
    
    return dataframe

# %%
best_btree
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
def run_model_familiy_datasets(df_train, df_test, name_attribute):
    
    # Modelo con la mejor combinacion de hiperparametros del punto 2.2
    
    dtree = DecisionTreeClassifier(max_depth=5, criterion='gini')
    
    completitud_accuracy_tamanio = {"completitud":[], "accuracy":[], "tamanio":[]}
    
    # Niveles de ruido
    
    for noise in np.arange(0.0,.35,.05):
        
        # Agregamos el ruido al attribute elegido
        
        df_noise = generate_dataset_with_noise(df_train, name_attribute, noise)
        
        scoring = ['accuracy']
        
        scores = cross_validate(dtree, # Instancia de árbol a entrenar en cada fold
                            df_noise.drop(columns=['target']).values, # X_train features
                            df_noise["target"].values, # Y_train targets
                            scoring=scoring, # Pedimos que para fold se ejecute esta lista de scorings
                            return_train_score = True, # Queremos ver los scorings de los training folds
                            return_estimator = True, # Ademas, pedimos que se nos devuelvan los dtrees de entrenados
                            cv=5, # Establecemos la cantidad de particiones para realizar la Validación cruzada
                            n_jobs = -1 # Pedimos que se ejecute en paralelo, utilizando todos los cores
                           )
        
        # Seleccionamos el mejor modelo
        
        best_dtree_index = np.argmax(scores["test_roc_auc"])
        best_btree = scores["estimator"][best_dtree_index]

        y_esperado = df_test['target'].values
        y_pred = best_btree.predict(df_test.drop(columns=['target']).values)

        accuracy = accuracy_score(y_esperado, y_pred)
        tamanio = best_btree.tree_.node_count

        completitud_accuracy_tamanio["completitud"].append(100.0*noise)
        completitud_accuracy_tamanio["accuracy"].append(accuracy)
        completitud_accuracy_tamanio["tamanio"].append(tamanio)
        
    return completitud_accuracy_tamanio

# %%
run_model_familiy_datasets(df_train, df_test, 'diff_time_start_end')
# Out:
#    percentage_noise  accuracy   roc_auc
# 0              0.05  0.746833  0.799200
# 1              0.10  0.747470  0.799496
# 2              0.15  0.744285  0.798659
# 3              0.20  0.746833  0.800558
# 4              0.25  0.746833  0.798391
# 5              0.30  0.746833  0.798391
# 6              0.35  0.746833  0.800542

# %% [markdown]
# ### La performance del modelo no parece verse afectada por el noise. Puede ser porque no es una varaible importante para el mismo?

# %% [markdown]
# ### c) Graficamos el tamaño del arbol (cantidad de nodos) en funcion del ruido

# %% [markdown]
# ### d) Graficamos la performance (accuracy) en funcion del ruido

# %% [markdown]
# ### e) Analizamos los resultados:

# %% [markdown]
# ## 3 Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Entrenamos el modelo con los datos de train y predecimos sobre test. Los resultamos que vamos a obtener son las probabilidades que el modelo asigna para cada clase posible (recordemos que en este caso son solo 2: compro o no compro)

# %%
clf = GaussianNB()

scoring = ['accuracy','roc_auc']

scores_nb = cross_validate(clf, # Instancia de árbol a entrenar en cada fold
                        df_train.drop(columns=['target']).values, # X_train features
                        df_train["target"].values, # Y_train targets
                        scoring=scoring, # Pedimos que para fold se ejecute esta lista de scorings
                        return_train_score = True, # Queremos ver los scorings de los training folds
                        return_estimator = True, # Ademas, pedimos que se nos devuelvan los dtrees de entrenados
                        cv=5, # Establecemos la cantidad de particiones para realizar la Validación cruzada
                        n_jobs = -1 # Pedimos que se ejecute en paralelo, utilizando todos los cores
                       )
scores_nb
# Out:
# {'fit_time': array([0.00942445, 0.00892735, 0.00793743, 0.0084331 , 0.00347209]),
#  'score_time': array([0.00446486, 0.00396872, 0.00347137, 0.00347185, 0.00148821]),
#  'estimator': (GaussianNB(priors=None, var_smoothing=1e-09),
#   GaussianNB(priors=None, var_smoothing=1e-09),
#   GaussianNB(priors=None, var_smoothing=1e-09),
#   GaussianNB(priors=None, var_smoothing=1e-09),
#   GaussianNB(priors=None, var_smoothing=1e-09)),
#  'test_accuracy': array([0.55414013, 0.57643312, 0.5955414 , 0.58146965, 0.55910543]),
#  'train_accuracy': array([0.60366826, 0.6092504 , 0.60287081, 0.59681275, 0.59920319]),
#  'test_roc_auc': array([0.58945959, 0.60617494, 0.65887699, 0.62671485, 0.61060755]),
#  'train_roc_auc': array([0.68958206, 0.68896139, 0.67996795, 0.68500599, 0.67967004])}

# %%
cv_5_fold_resultados_naive_bayes = pd.DataFrame(scores_nb)

cv_5_fold_resultados_naive_bayes.drop(["fit_time","score_time","estimator"],axis=1,inplace=True)

cv_5_fold_resultados_naive_bayes
# Out:
#    test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# 0       0.554140        0.603668      0.589460       0.689582
# 1       0.576433        0.609250      0.606175       0.688961
# 2       0.595541        0.602871      0.658877       0.679968
# 3       0.581470        0.596813      0.626715       0.685006
# 4       0.559105        0.599203      0.610608       0.679670

# %%
cv_5_fold_resultados_naive_bayes.describe()
# Out:
#        test_accuracy  train_accuracy  test_roc_auc  train_roc_auc
# count       5.000000        5.000000      5.000000       5.000000
# mean        0.573338        0.602361      0.618367       0.684637
# std         0.016881        0.004748      0.026245       0.004737
# min         0.554140        0.596813      0.589460       0.679670
# 25%         0.559105        0.599203      0.606175       0.679968
# 50%         0.576433        0.602871      0.610608       0.685006
# 75%         0.581470        0.603668      0.626715       0.688961
# max         0.595541        0.609250      0.658877       0.689582

# %%
best_naive_bayes_index = np.argmax(scores_nb["test_accuracy"]*scores_nb["test_roc_auc"])

# %%
best_naive_bayes = scores["estimator"][best_naive_bayes_index]

y_esperado_nb = df_test.target.values

y_pred_nb = best_naive_bayes.predict(df_test[feature_columns].values)

# %% [markdown]
# #### Accuracy del modelo naive bayes sobre el dataset de test

# %%
print("Score validation: " + str(accuracy_score(y_esperado_nb, y_pred_nb)))
# Out:
# Score validation: 0.673469387755102

# %% [markdown]
# #### Obtenemos las probabilidades de pertenecia a cada clase que el modelo calcula para cada observacion de test

# %%
def prior_probabilities(model, dataset):
    
    y_pred = model.predict_proba(dataset.drop(columns=['target']))
    
    array_pred_class_0 = []
    
    array_pred_class_1 = []
    
    for prediction in y_pred:
        
        array_pred_class_0.append('{:f}'.format(prediction[0]))
        
        array_pred_class_1.append('{:f}'.format(prediction[1]))
    
    d = {'proba_class_0': array_pred_class_0, 'proba_class_1': array_pred_class_1}
    
    df = pd.DataFrame(data=d)
    
    return df

# %%
prior_probabilities(best_naive_bayes, df_test).head()
# Out:
#   proba_class_0 proba_class_1
# 0      0.833333      0.166667
# 1      0.216667      0.783333
# 2      0.216667      0.783333
# 3      0.833333      0.166667
# 4      0.833333      0.166667

# %% [markdown]
# #### Obtenemos las probabilidades condicionales para un atributo del dataset

# %%
def get_conditional_probabilities_attribute(dataframe, name_attribute):
    
    df = dataframe.copy()
    
    df['target_no'] = np.where(df['target'] == 0, 1, 0)
    
    d = {'target': ['sum'], 'target_no': ['sum']}

    df_cond = df.groupby([name_attribute]).agg(d)

    df_cond.columns = ['_'.join(col) for col in df_cond.columns.values]

    df_cond = df_cond.reset_index()

    df_cond['target_yes'] = round(df_cond['target_sum']/df_cond['target_sum'].sum(),3)
    
    df_cond['target_no'] = round(df_cond['target_no_sum']/df_cond['target_no_sum'].sum(),3)
    
    df_cond = df_cond.drop(columns=['target_sum', 'target_no_sum'])
    
    return df_cond

# %% [markdown]
# #### Por ejemplo, dado el valor de 1 para target, la probabilidad de que 'Android' tome el valor de 0 es de 0,594

# %%
df_test = get_conditional_probabilities_attribute(df_train, 'Android')

print(df_test.head())

df_test['target_yes'].sum()
# Out:
#    Android  target_yes  target_no
# 0      0.0       0.594      0.464
# 1      1.0       0.084      0.219
# 2      2.0       0.076      0.065
# 3      3.0       0.039      0.056
# 4      4.0       0.041      0.046
# 0.996
